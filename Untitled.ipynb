# %%
import cv2 as cv
import os
import tensorflow as tf
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 3
#       1 import cv2 as cv
#       2 import os
# ----> 3 import tensorflow as tf
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
# !pip install tensorflow-macos
# Out:
# ...
#   Using cached flatbuffers-25.9.23-py2.py3-none-any.whl.metadata (875 bytes)
# ...
#   Using cached packaging-25.0-py3-none-any.whl.metadata (3.3 kB)
# ...
#   Using cached six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# ...
#   Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl.metadata (61 kB)
# ...
#   Using cached werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# ...
#   Using cached pygments-2.19.2-py3-none-any.whl.metadata (2.5 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 227.0/227.0 MB 2.4 MB/s  0:01:46 eta 0:00:010:00:03
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 2.0 MB/s  0:00:05m 2.0 MB/s eta 0:00:01
# ...
# Using cached numpy-1.26.4-cp310-cp310-macosx_11_0_arm64.whl (14.0 MB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 2.1 MB/s  0:00:022.1 MB/s eta 0:00:01:01
# ...
# Using cached six-1.17.0-py2.py3-none-any.whl (11 kB)
# Using cached flatbuffers-25.9.23-py2.py3-none-any.whl (30 kB)
# ...

# %%
# !pip uninstall -y tensorflow tensorflow-macos keras tensorboard tensorflow-io-gcs-filesystem
# Out:
# Found existing installation: tensorflow 2.16.2
# Uninstalling tensorflow-2.16.2:
#   Successfully uninstalled tensorflow-2.16.2
# Found existing installation: tensorflow-macos 2.16.2
# Uninstalling tensorflow-macos-2.16.2:
#   Successfully uninstalled tensorflow-macos-2.16.2
# Found existing installation: keras 3.12.0
# Uninstalling keras-3.12.0:
#   Successfully uninstalled keras-3.12.0
# Found existing installation: tensorboard 2.16.2
# Uninstalling tensorboard-2.16.2:
#   Successfully uninstalled tensorboard-2.16.2
# Found existing installation: tensorflow-io-gcs-filesystem 0.37.1
# Uninstalling tensorflow-io-gcs-filesystem-0.37.1:
#   Successfully uninstalled tensorflow-io-gcs-filesystem-0.37.1

# %%
# !pip install --upgrade numpy
# Out:
# ...
#   Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl.metadata (62 kB)
# Using cached numpy-2.2.6-cp310-cp310-macosx_14_0_arm64.whl (5.3 MB)
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.26.4
#     Uninstalling numpy-1.26.4:
#       Successfully uninstalled numpy-1.26.4
# ...
